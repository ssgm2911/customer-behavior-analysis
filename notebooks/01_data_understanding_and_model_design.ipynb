# %% [markdown]
# # Data Understanding and Model Design

# %% [markdown]
# ## Business Objective

# %% [markdown]
# ## Load Raw Tables

# %% [markdown]
# ## Table Shapes

# %% [markdown]
# ## Primary Key Validation

# %% [markdown]
# ## Customer Identity Issue

# %% [markdown]
# ## Join Strategy

# %% [markdown]
# ## Proposed Data Model
